# %%
import geopandas as gpd
postcode_geopackage = gpd.read_file('cbs_pc4_2019.gpkg')
stations_geopackage = gpd.read_file('')
# Out:
#       postcode  aantal_inwoners  aantal_mannen  aantal_vrouwen  \
# 0         1184              630            315             315
# 1         1695             4185           2055            2130
# 2         1733             3370           1690            1675
# 3         1752              730            385             345
# 4         1965             6115           3050            3070
# ...        ...              ...            ...             ...
# 4063      9995              680            355             330
# 4064      9996               65             40              25
# 4065      9997              610            320             290
# 4066      9998              185            100              85
# 4067      9999              100             50              50
#
#       aantal_inwoners_0_tot_15_jaar  aantal_inwoners_15_tot_25_jaar  \
# 0                               115                              95
# 1                               565                             415
# ...

# %%
postcode_geometries = postcode_geopackage['geometry']
postcodes = postcode_geopackage['postcode']
postcode_geometries.plot()
# Out:
# <Axes: >
